# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import nltk

# %%
nltk.download('all')
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to
# [nltk_data]    |     C:\Users\Atharv\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package abc is already up-to-date!
# [nltk_data]    | Downloading package alpino to
# [nltk_data]    |     C:\Users\Atharv\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package alpino is already up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     C:\Users\Atharv\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]    |     C:\Users\Atharv\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger_eng is already
# [nltk_data]    |       up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# ...

# %%
file = open('sample.txt' , 'r')
file
# Out:
# <_io.TextIOWrapper name='sample.txt' mode='r' encoding='cp1252'>

# %%
content = file.read()
content
# Out:
# "Torna fort is believed to have been constructed by the Shiva Panth in the 13th century. A Menghai Devi temple, also referred to as the Tornaji temple, is situated near the entrance of the fort. Malik Ahmed, a Bahamani ruler, captured this fort during the reign of Alauddin Khilji during the late 1470s.\n\nIn 1646, Shivaji captured this fort at the age of sixteen [citation needed], thus making it one of the first forts that would become one of the forts of the Maratha empire. Shivaji renamed the fort ' 'Prachandagad' ' as Torna, and constructed several monuments and towers within it.[2]\n\nIn the 18th century, the Mughal empire briefly gained control of this fort after the assassination of Shivaji's son Sambhaji raje. Aurangzeb, the then Mughal emperor, renamed this fort Futulgaib in recognition of the difficult defense the Mughals had to overcome to capture this fort. It was restored to the Maratha confederacy by the Treaty of Purandar."

# %%
from nltk.tokenize import sent_tokenize
sentence = sent_tokenize(content)
sentence
# Out:
# ['Torna fort is believed to have been constructed by the Shiva Panth in the 13th century.',
#  'A Menghai Devi temple, also referred to as the Tornaji temple, is situated near the entrance of the fort.',
#  'Malik Ahmed, a Bahamani ruler, captured this fort during the reign of Alauddin Khilji during the late 1470s.',
#  'In 1646, Shivaji captured this fort at the age of sixteen [citation needed], thus making it one of the first forts that would become one of the forts of the Maratha empire.',
#  "Shivaji renamed the fort ' 'Prachandagad' ' as Torna, and constructed several monuments and towers within it.",
#  "[2]\n\nIn the 18th century, the Mughal empire briefly gained control of this fort after the assassination of Shivaji's son Sambhaji raje.",
#  'Aurangzeb, the then Mughal emperor, renamed this fort Futulgaib in recognition of the difficult defense the Mughals had to overcome to capture this fort.',
#  'It was restored to the Maratha confederacy by the Treaty of Purandar.']

# %%
from nltk.tokenize import word_tokenize
words =  word_tokenize(content)
words
# Out:
# ['Torna',
#  'fort',
#  'is',
#  'believed',
#  'to',
#  'have',
#  'been',
#  'constructed',
#  'by',
#  'the',
#  'Shiva',
#  'Panth',
#  'in',
#  'the',
#  '13th',
#  'century',
#  '.',
#  'A',
#  'Menghai',
#  'Devi',
#  'temple',
#  ',',
#  'also',
#  'referred',
#  'to',
#  'as',
#  'the',
#  'Tornaji',
#  'temple',
#  ',',
#  'is',
#  'situated',
#  'near',
#  'the',
#  'entrance',
#  'of',
#  'the',
#  'fort',
#  '.',
#  'Malik',
#  'Ahmed',
#  ',',
#  'a',
#  'Bahamani',
#  'ruler',
#  ',',
#  'captured',
#  'this',
#  'fort',
#  'during',
#  'the',
#  'reign',
#  'of',
#  'Alauddin',
#  'Khilji',
#  'during',
#  'the',
#  'late',
#  '1470s',
#  '.',
#  'In',
#  '1646',
#  ',',
#  'Shivaji',
#  'captured',
#  'this',
#  'fort',
#  'at',
#  'the',
#  'age',
#  'of',
#  'sixteen',
#  '[',
#  'citation',
#  'needed',
#  ']',
#  ',',
#  'thus',
#  'making',
#  'it',
#  'one',
#  'of',
#  'the',
#  'first',
#  'forts',
#  'that',
#  'would',
#  'become',
#  'one',
#  'of',
# ...

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
stopWords =  set(stopwords.words('english'))
print(stopWords)
# Out:
# {"she'll", "we'd", 'further', 'hadn', 'where', 'you', 'd', 'in', 'which', 'him', 'not', 'very', 'are', 'only', 'his', 'again', 'it', 'wouldn', 'i', 'weren', 'between', 'no', 'when', 'doesn', "we'll", 'being', 'each', 'its', "doesn't", 'while', 'can', 'do', 'other', 'down', 'ours', 'ma', 'hers', 'then', "weren't", 'did', 'to', 'she', "they'll", "he's", 'll', 'the', 'how', "you're", 'isn', 'me', 've', 'will', 'there', "i'd", "you've", 'be', 'more', 'an', 's', 'they', 'up', 'and', "needn't", "isn't", 'theirs', "you'll", 'myself', "you'd", 'against', 'such', "wouldn't", 'has', 'into', "she'd", 'own', 'were', 'those', 'just', 'my', 'we', "we've", 'should', 'shouldn', 'that', 'any', 'was', 'yourself', 'haven', 'am', 'here', 'or', 'needn', 'he', 'now', "aren't", 'does', 'over', "couldn't", 'our', 'of', "they're", 'too', 'doing', 'after', "he'd", 'below', 'herself', "they've", "shan't", 'before', 'don', 'them', "i'm", 'yourselves', 'themselves', 'with', 'what', "shouldn't", 'during', "wasn't
# ...

# %%
for sen in sentence:
   Words = word_tokenize(sen)
   filteredWords = [word.lower() for word in Words if word.lower() not in stopWords]
   print(f'Words without stopwords : {filteredWords}')
   print(f'Words with stopwords : {Words}')
# Out:
# Words without stopwords : ['torna', 'fort', 'believed', 'constructed', 'shiva', 'panth', '13th', 'century', '.']
# Words with stopwords : ['Torna', 'fort', 'is', 'believed', 'to', 'have', 'been', 'constructed', 'by', 'the', 'Shiva', 'Panth', 'in', 'the', '13th', 'century', '.']
# Words without stopwords : ['menghai', 'devi', 'temple', ',', 'also', 'referred', 'tornaji', 'temple', ',', 'situated', 'near', 'entrance', 'fort', '.']
# Words with stopwords : ['A', 'Menghai', 'Devi', 'temple', ',', 'also', 'referred', 'to', 'as', 'the', 'Tornaji', 'temple', ',', 'is', 'situated', 'near', 'the', 'entrance', 'of', 'the', 'fort', '.']
# Words without stopwords : ['malik', 'ahmed', ',', 'bahamani', 'ruler', ',', 'captured', 'fort', 'reign', 'alauddin', 'khilji', 'late', '1470s', '.']
# Words with stopwords : ['Malik', 'Ahmed', ',', 'a', 'Bahamani', 'ruler', ',', 'captured', 'this', 'fort', 'during', 'the', 'reign', 'of', 'Alauddin', 'Khilji', 'during', 'the', 'late', '1470s', '.']
# ...

# %%
print(f'POS Tagging {nltk.pos_tag(filteredWords)}')
# Out:
# POS Tagging [('restored', 'VBN'), ('maratha', 'NNS'), ('confederacy', 'NN'), ('treaty', 'NN'), ('purandar', 'NN'), ('.', '.')]

# %%
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer

# %%
stemmer = PorterStemmer()
for word in Words:
   print(f'{word} -> After Stemming = {stemmer.stem(word)}')
# Out:
# It -> After Stemming = it
# was -> After Stemming = wa
# restored -> After Stemming = restor
# to -> After Stemming = to
# the -> After Stemming = the
# Maratha -> After Stemming = maratha
# confederacy -> After Stemming = confederaci
# by -> After Stemming = by
# the -> After Stemming = the
# Treaty -> After Stemming = treati
# of -> After Stemming = of
# Purandar -> After Stemming = purandar
# . -> After Stemming = .

# %%
lemmatizer = WordNetLemmatizer()
for word in Words:
   print(f'{word} : {lemmatizer.lemmatize(word)}')
# Out:
# It : It
# was : wa
# restored : restored
# to : to
# the : the
# Maratha : Maratha
# confederacy : confederacy
# by : by
# the : the
# Treaty : Treaty
# of : of
# Purandar : Purandar
# . : .

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
import numpy as np
# Sample small documents (corpus)
documents = [
''' 
   Torna fort is believed to have been constructed by the Shiva Panth in the 13th century. A Menghai Devi temple, also referred to as the Tornaji temple, is situated near the entrance of the fort. Malik Ahmed, a Bahamani ruler, captured this fort during the reign of Alauddin Khilji during the late 1470s.

In 1646, Shivaji captured this fort at the age of sixteen [citation needed], thus making it one of the first forts that would become one of the forts of the Maratha empire. Shivaji renamed the fort ' 'Prachandagad' ' as Torna, and constructed several monuments and towers within it.[2]

In the 18th century, the Mughal empire briefly gained control of this fort after the assassination of Shivaji's son Sambhaji raje. Aurangzeb, the then Mughal emperor, renamed this fort Futulgaib in recognition of the difficult defense the Mughals had to overcome to capture this fort. It was restored to the Maratha confederacy by the Treaty of Purandar.
 '''
]
# Initialize the TfidfVectorizer
vectorizer = TfidfVectorizer()
# Fit and transform the documents into TF-IDF features
tfidf_matrix = vectorizer.fit_transform(documents)
# Get the feature names (words)
words = vectorizer.get_feature_names_out()


tf = tfidf_matrix.toarray()
# Get the Inverse Document Frequency (IDF) values
idf = vectorizer.idf_
# Convert the TF-IDF matrix to a dense matrix and display the result
dense_matrix = tfidf_matrix.todense()
# Print the TF, IDF, and TF-IDF values
print("TF Matrix:")
print(tf)
print("\nIDF values:")
print(idf)
print("\nTF-IDF Matrix (Dense Representation):")
print(dense_matrix)
# Display words, TF, IDF, and corresponding TF-IDF values for each document
for i, doc in enumerate(documents):
   print(f"\nDocument {i + 1}:")
   for word, tf_value, idf_value, tfidf_value in zip(words, tf[i], idf,dense_matrix[i].tolist()[0]):
      if tf_value > 0: # Display only words with non-zero TF
         print(f"{word}: TF = {tf_value:.4f}, IDF = {idf_value:.4f}, TF-IDF= {tfidf_value:.4f}")
# Out:
# TF Matrix:
# [[0.0358748 0.0358748 0.0358748 0.0358748 0.0358748 0.0358748 0.0358748
#   0.0358748 0.0358748 0.0717496 0.0717496 0.0358748 0.0358748 0.0358748
#   0.0358748 0.0358748 0.0358748 0.0358748 0.0358748 0.0717496 0.0358748
#   0.0717496 0.0717496 0.0358748 0.0358748 0.0717496 0.0358748 0.0358748
#   0.0358748 0.0358748 0.0717496 0.0358748 0.0717496 0.0358748 0.0358748
#   0.2869984 0.0717496 0.0358748 0.0358748 0.0358748 0.0358748 0.1434992
#   0.0717496 0.1076244 0.0358748 0.0358748 0.0358748 0.0358748 0.0717496
#   0.0358748 0.0358748 0.0717496 0.0358748 0.0358748 0.0358748 0.358748
#   0.0717496 0.0358748 0.0358748 0.0358748 0.0358748 0.0358748 0.0358748
#   0.0358748 0.0358748 0.0717496 0.0358748 0.0358748 0.0358748 0.0358748
#   0.0358748 0.1076244 0.0358748 0.0358748 0.0358748 0.0717496 0.0358748
#   0.717496  0.0358748 0.179374  0.0358748 0.179374  0.0717496 0.0358748
#   0.0358748 0.0358748 0.0358748 0.0358748 0.0358748]]
#
# IDF values:
# ...
