# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Load the dataset into a pandas DataFrame
df = pd.read_csv('iris.csv')
# Display the first few rows of the dataset
print(df.head())
# Out:
#    sepal_length  sepal_width  petal_length  petal_width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
numeric_features=df[['sepal_length','sepal_width','petal_length','petal_width']]

# %%
categorical_features=df['class']

# %%
numeric_features.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
categorical_features.head()
# Out:
# 0    Iris-setosa
# 1    Iris-setosa
# 2    Iris-setosa
# 3    Iris-setosa
# 4    Iris-setosa
# Name: class, dtype: object

# %%
sns.histplot(df['sepal_length'])
# Out:
# <Axes: xlabel='sepal_length', ylabel='Count'>

# %%
sns.histplot(df['sepal_width'])
# Out:
# <Axes: xlabel='sepal_width', ylabel='Count'>

# %%
sns.histplot(df['petal_length'])
# Out:
# <Axes: xlabel='petal_length', ylabel='Count'>

# %%
sns.histplot(df['petal_width'])
# Out:
# <Axes: xlabel='petal_width', ylabel='Count'>

# %%
sns.boxplot(y='sepal_length',x='class',data=df)
plt.show()

# %%
sns.boxplot(y='sepal_width',x='class',data=df)
# Out:
# <Axes: xlabel='class', ylabel='sepal_width'>

# %%
sns.boxplot(y='petal_length',x='class',data=df)
# Out:
# <Axes: xlabel='class', ylabel='petal_length'>

# %%
sns.boxplot(y='petal_width',x='class',data=df)
# Out:
# <Axes: xlabel='class', ylabel='petal_width'>
